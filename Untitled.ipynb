# %%
from PIL import Image
from autocrop import Cropper

c = Cropper()

# %%
loc = 'tests/data/macbeth.jpg'
img = Image.open(loc)
img.resize((img.width // 2, img.height // 2))
# Out:
# <PIL.Image.Image image mode=L size=500x667 at 0x7F5BF49F94D0>

# %%
img_array = c.crop(loc)
Image.fromarray(img_array)
# Out:
# <PIL.Image.Image image mode=RGB size=500x500 at 0x7F5BF6BF9990>

# %%
c.crop('asdf')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/projects/autocrop/autocrop/autocrop.py in crop(self, path_or_array)
#     180         try:
# --> 181             img_height, img_width = image.shape[:2]
#     182         except AttributeError:
#
# AttributeError: 'NoneType' object has no attribute 'shape'
#
# During handling of the above exception, another exception occurred:
#
# ImageReadError                            Traceback (most recent call last)
# <ipython-input-17-acc85154b1d0> in <module>
# ----> 1 c.crop('asdf')
#
# ~/projects/autocrop/autocrop/autocrop.py in crop(self, path_or_array)
#     181             img_height, img_width = image.shape[:2]
#     182         except AttributeError:
# --> 183             raise ImageReadError
#     184         minface = int(np.sqrt(img_height ** 2 + img_width ** 2) / MINFACE)
#     185
#
# ImageReadError:

# %%
args = ('a', 'b', 'c', 'd')
a, b, c, d = args

# %%
a
# Out:
# 'a'

# %%
from autocrop.cli import size
size(-3)
# Out:
# ---------------------------------------------------------------------------
# ArgumentTypeError                         Traceback (most recent call last)
# <ipython-input-22-30738e521a10> in <module>
#       1 from autocrop.cli import size
# ----> 2 size(-3)
#
# ~/projects/autocrop/autocrop/cli.py in size(i)
#     181         return i
#     182     else:
# --> 183         raise argparse.ArgumentError(error)
#     184
#     185
#
# ArgumentTypeError: Invalid pixel size

# %%
import argparse

i = 'asdf'
try:
    int(i)
except ValueError as e:
    raise argparse.ArgumentTypeError(e)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-de9e862d9880> in <module>
#       4 try:
# ----> 5     int(i)
#       6 except ValueError as e:
#
# ValueError: invalid literal for int() with base 10: 'asdf'
#
# During handling of the above exception, another exception occurred:
#
# ArgumentTypeError                         Traceback (most recent call last)
# <ipython-input-28-de9e862d9880> in <module>
#       5     int(i)
#       6 except ValueError as e:
# ----> 7     raise argparse.ArgumentTypeError(e)
#
# ArgumentTypeError: invalid literal for int() with base 10: 'asdf'

# %%
argparse.ArgumentTypeError('padUp', i)
# Out:
# argparse.ArgumentTypeError('padUp', 'asdf')
